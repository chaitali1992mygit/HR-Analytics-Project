# %% [markdown]
# # HR ANALYTICS PROJECT

# %% [markdown]
# ## Importing Libreries

# %%
#Import libreries 

import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sn
import pickle

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Importing all neccessory Libreries

# %% [markdown]
# ## Importing dataset

# %%
#Import the dataset

data= pd.read_csv(r"C:\Users\Chaitali Nakade\OneDrive\Desktop\dataset\HR_ANALYTICS.csv")
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# Importing the dataset and see all columns with first five rows.

# %% [markdown]
# ## Shape of data with number of rows and columns

# %%
data.shape
# Out:
# (1470, 35)

# %% [markdown]
# There are 1470 Rows and 35 Columns in dataset

# %% [markdown]
# ## Detailed description

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# We can see the detailed description of all the rows and columns like count, mean value, standard deviation, minimum and maximum value.

# %% [markdown]
# # Datatypes of all columns

# %%
data.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# We have object data type in Attrition, BusinessTravel, Department, EducationField, Gender, JobRole, MaritalStatus, Over18, and OverTime.
#
# Rest all are having integer data type.
#
# Attrition is a target variable.

# %% [markdown]
# # Checking is there any null value

# %%
#check is there any null value present in any column

data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# There are NO missing values in dataset.
#
# So, safe to proceed further.

# %% [markdown]
# ### visualization of missing values by heatmap

# %%
plt.figure(figsize=[16,6])
sn.heatmap(data.isnull())
plt.title("NULL VALUES")
plt.show()

# %% [markdown]
# we can see there is no missing values.

# %%
data['Attrition'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
data['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
# Replace Attrition column to binary encoder
data['Attrition'] = data['Attrition'].replace({'Yes':1, 'No':0})

# %% [markdown]
# Encode the attrition so it will be visualize in EDA part.

# %% [markdown]
# ## EDA (Exploratory Data Analysis)

# %% [markdown]
# ### Visualization (Uni Variate analysis)
# Uni variate analysis works with only one variable, hence it is called uni variate.

# %%
fe = data[['Age', 'Attrition', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel','TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']]

# %%
#Relationship Visualizing

plt.figure(figsize = (20,45), facecolor = 'white')
plotnumber = 1

for column in fe:
    if plotnumber <= 35: # as we see there are eight columns in the data
        ax = plt.subplot(11,3,plotnumber)
        sn.distplot(fe[column], color = 'g')
        plt.xlabel(column,fontsize=15)
        
    plotnumber += 1
plt.show()

# %% [markdown]
# As we can see there are maximum columns is having Skewness in it but some columns are catogorical in nature so in that no need to check skewness.
#
# MonthlyIncome, TotalWorkingYears, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion and YearsWithCurrManager is having skewness in it

# %% [markdown]
# #### Histplot

# %%
#Relationship Visualizing

plt.figure(figsize = (20,45), facecolor = 'white')
plotnumber = 1

for column in fe:
    if plotnumber <= 35: # as we see there are eight columns in the data
        ax = plt.subplot(11,3,plotnumber)
        sn.histplot(fe[column], color = 'c')
        plt.xlabel(column,fontsize=15)
        
    plotnumber += 1
plt.show()

# %% [markdown]
# ##### Attrition is a targate variable and it is having binary classes. so, it is a binaryclassification problem.

# %% [markdown]
# ### Analysis through boxplot

# %%
#Relationship Visualizing

plt.figure(figsize = (20,50), facecolor = 'white')
plotnumber = 1

for column in fe:
    if plotnumber <= 35: # as we see there are eight columns in the data
        ax = plt.subplot(11,3,plotnumber)
        sn.boxplot(fe[column])
        plt.xlabel(column,fontsize=15)
        
    plotnumber += 1
plt.show()

# %% [markdown]
# ##### As we have seen MonthlyIncome, TotalWorkingYears, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion and YearsWithCurrManager is having outliers in it.

# %% [markdown]
# ## Bi variate analysis
# Bi variate analysis is works with two variables.

# %%
#Relationship Visualizing

plt.figure(figsize = (20,45), facecolor = 'white')
plotnumber = 1

for column in data:
    if plotnumber <= 35:
        ax = plt.subplot(12,3,plotnumber)
        plt.scatter(data[column],data['Attrition'], color='g')
        plt.xlabel(column,fontsize=15)
        plt.ylabel('Attrition', fontsize=15)
    plotnumber += 1
plt.tight_layout()

# %% [markdown]
# As we have seen in the plot all columns are having categorical data in it with binary classification.

# %% [markdown]
# ## Multi Variate analysis
# Multi variate analysis find the relationship with all variables.
# Now we will visualize the data and check the coiefficient of multicollinearity

# %%
data_cor = data.corr().abs()

plt.figure(figsize = (20,15))
sn.heatmap(data_cor, vmin=-1, vmax= 1, annot=True, square=True,
          center=0, fmt='.1g', linewidths=.1)
plt.tight_layout()

# %% [markdown]
# As shown in attrition and hourlyrate are weekly correlated with each other.
#
# and other columns are having good correlation value with each other.

# %% [markdown]
# ##### Find out which columns are positively and negatively correlated with each other

# %%
plt.figure(figsize=(22,7))
data.corr()['Attrition'].sort_values(ascending = False).drop(['Attrition']).plot(kind = 'bar', color = 'y')
plt.xlabel('Feature', fontsize = 15)
plt.ylabel('Attrition', fontsize = 15)
plt.title('correlation', fontsize = 20)
plt.show()

# %% [markdown]
# as we have saw in the plot Performancerating, employeeecount and standardhours and target variable(attrition) is having very less correlation with target variable other. So, we can drop that column.

# %% [markdown]
# #### After visualization conclude that all input variables are having some/good amount relationship with target variable. Now proceed futher for next steps:

# %%
data
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          1      Travel_Rarely       1102                   Sales
# 1      49          0  Travel_Frequently        279  Research & Development
# 2      37          1      Travel_Rarely       1373  Research & Development
# 3      33          0  Travel_Frequently       1392  Research & Development
# 4      27          0      Travel_Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1465   36          0  Travel_Frequently        884  Research & Development
# 1466   39          0      Travel_Rarely        613  Research & Development
# 1467   27          0      Travel_Rarely        155  Research & Development
# 1468   49          0  Travel_Frequently       1023                   Sales
# 1469   34          0      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# # Encoding and drop column
# #### 1. Encode/Drop BusinessTravel column

# %%
# Check unique values of Name column
data['BusinessTravel'].unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
#value caounts of Name column
data['BusinessTravel'].value_counts()
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %%
#As we can see bussiness travel column is having 71% similar data so, we can drop that column
#drop bussinesstravel column
data=data.drop(['BusinessTravel'], axis=1)

# %% [markdown]
# ###### Result after dropin BussinessTravel column

# %% [markdown]
# #### 2. Encode Department column using binary encoder

# %%
# Check unique values of Department column
data['Department'].unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
#value caounts of Department column
data['Department'].value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
#import label encoder
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
data["Department"] = le.fit_transform(data["Department"])

# %%
# Check unique values of Name column
data['Department'].unique()
# Out:
# array([2, 1, 0])

# %% [markdown]
# ###### Result after encoding Department column with label encoder

# %% [markdown]
# #### 3. Encode/Drop the EducationField column

# %%
# Check unique values of EducationField column
data['EducationField'].unique()
# Out:
# array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)

# %%
#value caounts of Department column
data['EducationField'].value_counts()
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %%
#import label encoder
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
data["EducationField"] = le.fit_transform(data["EducationField"])

# %%
# Check unique values of Department column
data['EducationField'].unique()
# Out:
# array([1, 4, 3, 2, 5, 0])

# %% [markdown]
# ###### Result after EducationField Department column with label encoder

# %%
data.dtypes
# Out:
# Age                          int64
# Attrition                    int64
# DailyRate                    int64
# Department                   int32
# DistanceFromHome             int64
# Education                    int64
# EducationField               int32
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# ...

# %% [markdown]
# ####  4. encode sex column

# %%
# Check unique values of Gender column
data['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
data['Gender'].value_counts()
# Out:
# Male      882
# Female    588
# Name: Gender, dtype: int64

# %%
# Replace Gender column to binary encoder
data['Gender'] = data['Gender'].replace({'Male':1, 'Female':0})

# %% [markdown]
# ###### Result after Gender Department column with binary encoder

# %% [markdown]
# #### 5. Encode JobRole column

# %%
# Check unique values of EducationField column
data['JobRole'].unique()
# Out:
# array(['Sales Executive', 'Research Scientist', 'Laboratory Technician',
#        'Manufacturing Director', 'Healthcare Representative', 'Manager',
#        'Sales Representative', 'Research Director', 'Human Resources'],
#       dtype=object)

# %%
# Check unique values of EducationField column
data['JobRole'].value_counts()
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %%
#import label encoder
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
data["JobRole"] = le.fit_transform(data["JobRole"].values.reshape(-1,1))

# %%
data['JobRole'].unique()
# Out:
# array([7, 6, 2, 4, 0, 3, 8, 5, 1])

# %% [markdown]
# ###### Result after Gender JobRole column with Ordinal encoder

# %% [markdown]
# #### 6. Encode MaritalStatus column

# %%
# Check unique values of Gender column
data['MaritalStatus'].unique()
# Out:
# array(['Single', 'Married', 'Divorced'], dtype=object)

# %%
data['MaritalStatus'].value_counts()
# Out:
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64

# %%
#import label encoder
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

data["MaritalStatus"] = le.fit_transform(data["MaritalStatus"])
data['MaritalStatus'].unique()
# Out:
# array([2, 1, 0])

# %% [markdown]
# ###### Result after Gender MaritalStatus column with Label encoder

# %% [markdown]
# #### 7.Encode/drop Over18 column

# %%
# Check unique values of over18 column
data['Over18'].unique()
# Out:
# array(['Y'], dtype=object)

# %%
# Check unique values of Gender column
data['Over18'].value_counts()
# Out:
# Y    1470
# Name: Over18, dtype: int64

# %%
#drop Over18 column
data=data.drop(['Over18'], axis=1)

# %% [markdown]
# all values of Over18 column is similar so we can drop that column.

# %% [markdown]
# ###### Result after Over18 column will drop

# %% [markdown]
# #### 8. Encode OverTime column

# %%
# Check unique values of OverTime column
data['OverTime'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
data['OverTime'].value_counts()
# Out:
# No     1054
# Yes     416
# Name: OverTime, dtype: int64

# %%
# Replace OverTime column to binary encoder
data['OverTime'] = data['OverTime'].replace({'Yes':1, 'No':0})

# %% [markdown]
# ###### Result after encoding OverTime column with binary encoder

# %% [markdown]
# ##### 9.Drop HourlyRate column

# %%
# Check unique values of over18 column
data['HourlyRate'].unique()
# Out:
# array([ 94,  61,  92,  56,  40,  79,  81,  67,  44,  84,  49,  31,  93,
#         50,  51,  80,  96,  78,  45,  82,  53,  83,  58,  72,  48,  42,
#         41,  86,  97,  75,  33,  37,  73,  98,  36,  47,  71,  30,  43,
#         99,  59,  95,  57,  76,  87,  66,  55,  32,  52,  70,  62,  64,
#         63,  60, 100,  46,  39,  77,  35,  91,  54,  34,  90,  65,  88,
#         85,  89,  68,  69,  74,  38], dtype=int64)

# %%
#drop HourlyRate column
data=data.drop(['HourlyRate'], axis=1)

# %% [markdown]
# #### 10.Drop EmployeeCount column

# %%
# poor correlation with target variable
#drop EmployeeCount column
data=data.drop(['EmployeeCount'], axis=1)

# %% [markdown]
# #### 11.Drop StandardHours column

# %%
# poor correlation with target variable
#drop StandardHours column
data=data.drop(['StandardHours'], axis=1)

# %% [markdown]
# #### 12.Drop PerformanceRating column

# %%
# Check unique values of Department column
data['EmployeeNumber'].unique()
# Out:
# array([   1,    2,    4, ..., 2064, 2065, 2068], dtype=int64)

# %%
data['EmployeeNumber'].value_counts()
# Out:
# 2046    1
# 641     1
# 644     1
# 645     1
# 647     1
#        ..
# 1364    1
# 1367    1
# 1368    1
# 1369    1
# 2048    1
# Name: EmployeeNumber, Length: 1470, dtype: int64

# %%
data=data.drop(['EmployeeNumber'], axis=1)

# %% [markdown]
# EmployeeNumber is having all unique value, so we can drop that column.

# %% [markdown]
# ### after encoding check the correlation with target variable

# %%
plt.figure(figsize=(22,7))
data.corr()['Attrition'].sort_values(ascending = False).drop(['Attrition']).plot(kind = 'bar', color = 'y')
plt.xlabel('Feature', fontsize = 15)
plt.ylabel('Attrition', fontsize = 15)
plt.title('correlation', fontsize = 20)
plt.show()

# %%
#drop PerformanceRating column
data=data.drop(['PerformanceRating'], axis=1)

# %% [markdown]
# visualization after dropping and encoding poor correlative columns.

# %%
#datatypes after dropping and encoding poor correlative columns.
data.dtypes
# Out:
# Age                         int64
# Attrition                   int64
# DailyRate                   int64
# Department                  int32
# DistanceFromHome            int64
# Education                   int64
# EducationField              int32
# EnvironmentSatisfaction     int64
# Gender                      int64
# JobInvolvement              int64
# JobLevel                    int64
# JobRole                     int32
# JobSatisfaction             int64
# MaritalStatus               int32
# MonthlyIncome               int64
# MonthlyRate                 int64
# NumCompaniesWorked          int64
# OverTime                    int64
# PercentSalaryHike           int64
# RelationshipSatisfaction    int64
# StockOptionLevel            int64
# TotalWorkingYears           int64
# TrainingTimesLastYear       int64
# WorkLifeBalance             int64
# YearsAtCompany              int64
# YearsInCurrentRole          int64
# YearsSinceLastPromotion     int64
# ...

# %%
#dataset after dropping and encoding poor correlative columns.
data
# Out:
#       Age  Attrition  DailyRate  Department  DistanceFromHome  Education  \
# 0      41          1       1102           2                 1          2
# 1      49          0        279           1                 8          1
# 2      37          1       1373           1                 2          2
# 3      33          0       1392           1                 3          4
# 4      27          0        591           1                 2          1
# ...   ...        ...        ...         ...               ...        ...
# 1465   36          0        884           1                23          2
# 1466   39          0        613           1                 6          1
# 1467   27          0        155           1                 4          3
# 1468   49          0       1023           2                 2          3
# 1469   34          0        628           1                 8          3
#
#       EducationField  EnvironmentSatisfaction  Gender  JobInvolvement  ...  \
# ...

# %% [markdown]
# ## Remove outliers

# %%
data.dtypes
# Out:
# Age                         int64
# Attrition                   int64
# DailyRate                   int64
# Department                  int32
# DistanceFromHome            int64
# Education                   int64
# EducationField              int32
# EnvironmentSatisfaction     int64
# Gender                      int64
# JobInvolvement              int64
# JobLevel                    int64
# JobRole                     int32
# JobSatisfaction             int64
# MaritalStatus               int32
# MonthlyIncome               int64
# MonthlyRate                 int64
# NumCompaniesWorked          int64
# OverTime                    int64
# PercentSalaryHike           int64
# RelationshipSatisfaction    int64
# StockOptionLevel            int64
# TotalWorkingYears           int64
# TrainingTimesLastYear       int64
# WorkLifeBalance             int64
# YearsAtCompany              int64
# YearsInCurrentRole          int64
# YearsSinceLastPromotion     int64
# ...

# %% [markdown]
# as shown in above only 6 columns are contineous in nature.

# %% [markdown]
# ## 1.Outlier removal using Zscore

# %%
#In Zscore technique taking standard deviation 3
#for Zscore outlier removal technique import library from scipy


from scipy.stats import zscore

z_score= zscore(data[['MonthlyIncome', 'TotalWorkingYears', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']])
abs_z_score = np.abs(z_score)

filtering_entry = (abs_z_score < 3).all(axis = 1)

new_data = data[filtering_entry]

print("shape before and after")
print("shape before".ljust(20),":", data.shape)
print("shape after".ljust(20),":", new_data.shape)
print("Percentage Loss".ljust(20),":", (data.shape[0]-new_data.shape[0])/data.shape[0])
# Out:
# shape before and after
# shape before         : (1470, 28)
# shape after          : (1387, 28)
# Percentage Loss      : 0.05646258503401361

# %% [markdown]
# 5.64% data loss after using Zscore technique

# %%
(1387/1470)*100
# Out:
# 94.35374149659864

# %% [markdown]
# 94.35% data remains.

# %%
new_data.describe(include = 'all')
# Out:
#                Age    Attrition    DailyRate   Department  DistanceFromHome  \
# count  1387.000000  1387.000000  1387.000000  1387.000000       1387.000000
# mean     36.258111     0.165105   806.054074     1.260995          9.176640
# std       8.838767     0.371409   403.163183     0.526032          8.088602
# min      18.000000     0.000000   102.000000     0.000000          1.000000
# 25%      30.000000     0.000000   467.500000     1.000000          2.000000
# 50%      35.000000     0.000000   807.000000     1.000000          7.000000
# 75%      42.000000     0.000000  1160.000000     2.000000         14.000000
# max      60.000000     1.000000  1498.000000     2.000000         29.000000
#
#          Education  EducationField  EnvironmentSatisfaction       Gender  \
# count  1387.000000     1387.000000              1387.000000  1387.000000
# mean      2.896179        2.256669                 2.725306     0.602019
# ...

# %% [markdown]
# ## 2. Outlier Removing using IQR

# %% [markdown]
# ### from boxplot in EDA, we came to know that outliers present in following columns.

# %% [markdown]
# #### Visualize data again to check outliers are present at low side or high side

# %%
data2 = data

# %%
#features in which outliers are detected
fe = data2[['MonthlyIncome', 'TotalWorkingYears', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']]

# %%
plt.figure(figsize=(25,20))
graph = 1

for column in fe:
    if graph <= 30:
        ax = plt.subplot(4,3, graph)
        sn.boxplot(fe[column], color = 'c')
        plt.xlabel(column, fontsize = 20)
        
    graph+=1
plt.show()

# %%
#find the IQR (Inter Quantile Range) to identify outliers
#formula for finding IQR

#1st quantile 25%
q1 = data2.quantile(0.25)

#3rd quantile 75%
q3 = data2.quantile(0.75)

#IQR = Inter Quantile Range
iqr = q3-q1

# %%
data2.describe(include = 'all')
# Out:
#                Age    Attrition    DailyRate   Department  DistanceFromHome  \
# count  1470.000000  1470.000000  1470.000000  1470.000000       1470.000000
# mean     36.923810     0.161224   802.485714     1.260544          9.192517
# std       9.135373     0.367863   403.509100     0.527792          8.106864
# min      18.000000     0.000000   102.000000     0.000000          1.000000
# 25%      30.000000     0.000000   465.000000     1.000000          2.000000
# 50%      36.000000     0.000000   802.000000     1.000000          7.000000
# 75%      43.000000     0.000000  1157.000000     2.000000         14.000000
# max      60.000000     1.000000  1499.000000     2.000000         29.000000
#
#          Education  EducationField  EnvironmentSatisfaction       Gender  \
# count  1470.000000     1470.000000              1470.000000  1470.000000
# mean      2.912925        2.247619                 2.721769     0.600000
# ...

# %% [markdown]
# ## Outlier detection formula

# %% [markdown]
# #### Higher side ==> Q3 + (1.5 * IQR)
# #### Lower side ==> Q1 - (1.5 * IQR)

# %% [markdown]
# ##### Outliers removal from higher side

# %%
#as shown in boxplot we have outlier in higher side of MonthlyIncome 
#Remove outliers from higher side so, use higher side formula

income_out = (q3.MonthlyIncome + (1.5*(iqr.MonthlyIncome)))
income_out
# Out:
# 16581.0

# %%
index_out = np.where(data2['MonthlyIncome'] > income_out)
data2 = data2.drop(data2.index[index_out])
data2.shape
data2.reset_index()
# Out:
#       index  Age  Attrition  DailyRate  Department  DistanceFromHome  \
# 0         0   41          1       1102           2                 1
# 1         1   49          0        279           1                 8
# 2         2   37          1       1373           1                 2
# 3         3   33          0       1392           1                 3
# 4         4   27          0        591           1                 2
# ...     ...  ...        ...        ...         ...               ...
# 1351   1465   36          0        884           1                23
# 1352   1466   39          0        613           1                 6
# 1353   1467   27          0        155           1                 4
# 1354   1468   49          0       1023           2                 2
# 1355   1469   34          0        628           1                 8
#
#       Education  EducationField  EnvironmentSatisfaction  Gender  ...  \
# ...

# %% [markdown]
# after removing outliers from MonthlyIncome 1356 rows will remains in dataframe.

# %%
#as shown in boxplot we have outlier in higher side of TotalWorkingYears 
#Remove outliers from higher side so, use higher side formula

tw_out = (q3.TotalWorkingYears + (1.5*(iqr.TotalWorkingYears)))
tw_out
# Out:
# 28.5

# %%
index_out = np.where(data2['TotalWorkingYears'] > tw_out)
data2 = data2.drop(data2.index[index_out])
data2.shape
data2.reset_index()
# Out:
#       index  Age  Attrition  DailyRate  Department  DistanceFromHome  \
# 0         0   41          1       1102           2                 1
# 1         1   49          0        279           1                 8
# 2         2   37          1       1373           1                 2
# 3         3   33          0       1392           1                 3
# 4         4   27          0        591           1                 2
# ...     ...  ...        ...        ...         ...               ...
# 1321   1465   36          0        884           1                23
# 1322   1466   39          0        613           1                 6
# 1323   1467   27          0        155           1                 4
# 1324   1468   49          0       1023           2                 2
# 1325   1469   34          0        628           1                 8
#
#       Education  EducationField  EnvironmentSatisfaction  Gender  ...  \
# ...

# %% [markdown]
# after removing outliers from total working year 1326 rows will remains in dataframe.

# %%
#Check the Outliers for YearsAtCompany
#Remove outliers from higher side so, use higher side formula

yc_out = (q3.YearsAtCompany + (1.5*(iqr.YearsAtCompany)))
yc_out
# Out:
# 18.0

# %%
index_out = np.where(data2['YearsAtCompany'] > yc_out)
data2 = data2.drop(data2.index[index_out])
data2.shape
data2.reset_index()
# Out:
#       index  Age  Attrition  DailyRate  Department  DistanceFromHome  \
# 0         0   41          1       1102           2                 1
# 1         1   49          0        279           1                 8
# 2         2   37          1       1373           1                 2
# 3         3   33          0       1392           1                 3
# 4         4   27          0        591           1                 2
# ...     ...  ...        ...        ...         ...               ...
# 1280   1465   36          0        884           1                23
# 1281   1466   39          0        613           1                 6
# 1282   1467   27          0        155           1                 4
# 1283   1468   49          0       1023           2                 2
# 1284   1469   34          0        628           1                 8
#
#       Education  EducationField  EnvironmentSatisfaction  Gender  ...  \
# ...

# %% [markdown]
# after removing outliers from YearsAtCompany 1285 rows will remains in dataframe.

# %%
#Check the Outliers for YearsInCurrentRole
#Remove outliers from higher side so, use higher side formula

YearsInCurrentRole_out = (q3.YearsInCurrentRole + (1.5*(iqr.YearsInCurrentRole)))
YearsInCurrentRole_out
# Out:
# 14.5

# %%
index_out = np.where(data2['YearsInCurrentRole'] > YearsInCurrentRole_out)
data2 = data2.drop(data2.index[index_out])
data2.shape
data2.reset_index()
# Out:
#       index  Age  Attrition  DailyRate  Department  DistanceFromHome  \
# 0         0   41          1       1102           2                 1
# 1         1   49          0        279           1                 8
# 2         2   37          1       1373           1                 2
# 3         3   33          0       1392           1                 3
# 4         4   27          0        591           1                 2
# ...     ...  ...        ...        ...         ...               ...
# 1277   1465   36          0        884           1                23
# 1278   1466   39          0        613           1                 6
# 1279   1467   27          0        155           1                 4
# 1280   1468   49          0       1023           2                 2
# 1281   1469   34          0        628           1                 8
#
#       Education  EducationField  EnvironmentSatisfaction  Gender  ...  \
# ...

# %% [markdown]
# after removing outliers from YearsInCurrentRole 1282 rows will remains in dataframe.

# %%
#Check the Outliers for YearsSinceLastPromotion
#Remove outliers from higher side so, use higher side formula

YearsSinceLastPromotion_out = (q3.YearsSinceLastPromotion + (1.5*(iqr.YearsSinceLastPromotion)))
YearsSinceLastPromotion_out
# Out:
# 7.5

# %%
index_out = np.where(data2['YearsSinceLastPromotion'] > YearsSinceLastPromotion_out)
data2 = data2.drop(data2.index[index_out])
data2.shape
data2.reset_index()
# Out:
#       index  Age  Attrition  DailyRate  Department  DistanceFromHome  \
# 0         0   41          1       1102           2                 1
# 1         1   49          0        279           1                 8
# 2         2   37          1       1373           1                 2
# 3         3   33          0       1392           1                 3
# 4         4   27          0        591           1                 2
# ...     ...  ...        ...        ...         ...               ...
# 1228   1465   36          0        884           1                23
# 1229   1466   39          0        613           1                 6
# 1230   1467   27          0        155           1                 4
# 1231   1468   49          0       1023           2                 2
# 1232   1469   34          0        628           1                 8
#
#       Education  EducationField  EnvironmentSatisfaction  Gender  ...  \
# ...

# %% [markdown]
# after removing outliers from YearsSinceLastPromotion 1233 rows will remains in dataframe.

# %%
#Check the Outliers for YearsInCurrentRole
#Remove outliers from higher side so, use higher side formula

YearsWithCurrManager_out = (q3.YearsWithCurrManager + (1.5*(iqr.YearsWithCurrManager)))
YearsWithCurrManager_out
# Out:
# 14.5

# %%
index_out = np.where(data2['YearsWithCurrManager'] > YearsWithCurrManager_out)
data2 = data2.drop(data2.index[index_out])
data2.shape
data2.reset_index()
# Out:
#       index  Age  Attrition  DailyRate  Department  DistanceFromHome  \
# 0         0   41          1       1102           2                 1
# 1         1   49          0        279           1                 8
# 2         2   37          1       1373           1                 2
# 3         3   33          0       1392           1                 3
# 4         4   27          0        591           1                 2
# ...     ...  ...        ...        ...         ...               ...
# 1225   1465   36          0        884           1                23
# 1226   1466   39          0        613           1                 6
# 1227   1467   27          0        155           1                 4
# 1228   1468   49          0       1023           2                 2
# 1229   1469   34          0        628           1                 8
#
#       Education  EducationField  EnvironmentSatisfaction  Gender  ...  \
# ...

# %% [markdown]
# after removing outliers from YearsWithCurrManager 1230 rows will remains in dataframe.

# %% [markdown]
# #### After removing outliers using IQR technique there are 1230 rows will remains in dataset.
# Now, find how much data loss in IQR method

# %%
((1470-1230)/1470)*100
# Out:
# 16.3265306122449

# %% [markdown]
# 16.32% data loss in IQR method

# %%
((1230)/1470)*100
# Out:
# 83.6734693877551

# %% [markdown]
# 83.67% data remains after removing outliers using IQR technique

# %% [markdown]
# ### After applying Zscore and IQR technique to remove outliers. We conclude that less amount data will loss in Zscore technique so we will go with Zscore technique

# %% [markdown]
# ## Check the skewness and remove that

# %%
new_data.skew()
# Out:
# Age                         0.472280
# Attrition                   1.805983
# DailyRate                  -0.017078
# Department                  0.183919
# DistanceFromHome            0.954752
# Education                  -0.289024
# EducationField              0.544868
# EnvironmentSatisfaction    -0.325285
# Gender                     -0.417296
# JobInvolvement             -0.501401
# JobLevel                    1.126075
# JobRole                    -0.386843
# JobSatisfaction            -0.345612
# MaritalStatus              -0.160952
# MonthlyIncome               1.544770
# MonthlyRate                 0.030596
# NumCompaniesWorked          1.037715
# OverTime                    0.954751
# PercentSalaryHike           0.800592
# RelationshipSatisfaction   -0.295686
# StockOptionLevel            0.962332
# TotalWorkingYears           1.034487
# TrainingTimesLastYear       0.577614
# WorkLifeBalance            -0.557100
# YearsAtCompany              1.248623
# ...

# %% [markdown]
# As we see there are some variables are skewed, whoes value is not lies between -0.5 to +0.5 this range.
# 1. DistanceFromHome
# 2. MonthlyIncome
# 3. NumCompaniesWorked
# 4. PercentSalaryHike
# 5. TotalWorkingYears
# 6. YearsAtCompany
# 7. YearsInCurrentRole
# 8. YearsSinceLastPromotion
# 9. YearsWithCurrManager
#
# But we need to find skewness in only contineous data columns. So, we need to remove skewness on that.
#
# and maximum columns contains categorical values. so no need to remove skewness from that.

# %% [markdown]
# ### Check outliers datatype. If data types of skewed column is catogorical than no need to remove skewness from that variable.

# %% [markdown]
# ## Apply Log transformation to remove skewness

# %% [markdown]
# In log transformation, we will take the log of Continues skewed data and convert that into normal data(distribution)/less skewed data and in power transformation we will take the mean value in place of 0th value.

# %%
#applying log transformation on skewed columns

new_data['DistanceFromHome'] = np.log1p(new_data['DistanceFromHome'])
new_data['MonthlyIncome'] = np.log1p(new_data['MonthlyIncome'])
new_data['NumCompaniesWorked'] = np.log1p(new_data['NumCompaniesWorked'])
new_data['PercentSalaryHike'] = np.log1p(new_data['PercentSalaryHike'])
new_data['TotalWorkingYears'] = np.log1p(new_data['TotalWorkingYears'])
new_data['YearsAtCompany'] = np.log1p(new_data['YearsAtCompany'])
new_data['YearsInCurrentRole'] = np.log1p(new_data['YearsInCurrentRole'])
new_data['YearsSinceLastPromotion'] = np.log1p(new_data['YearsSinceLastPromotion'])
new_data['YearsWithCurrManager'] = np.log1p(new_data['YearsWithCurrManager'])

# %%
sn.distplot(new_data["DistanceFromHome"], color = 'g')
# Out:
# <AxesSubplot:xlabel='DistanceFromHome', ylabel='Density'>

# %%
sn.distplot(new_data["MonthlyIncome"], color = 'g')
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='Density'>

# %%
sn.distplot(new_data["NumCompaniesWorked"], color = 'g')
# Out:
# <AxesSubplot:xlabel='NumCompaniesWorked', ylabel='Density'>

# %%
sn.distplot(new_data["PercentSalaryHike"], color = 'g')
# Out:
# <AxesSubplot:xlabel='PercentSalaryHike', ylabel='Density'>

# %%
sn.distplot(new_data["TotalWorkingYears"], color = 'g')
# Out:
# <AxesSubplot:xlabel='TotalWorkingYears', ylabel='Density'>

# %%
sn.distplot(new_data["YearsAtCompany"], color = 'g')
# Out:
# <AxesSubplot:xlabel='YearsAtCompany', ylabel='Density'>

# %%
sn.distplot(new_data["YearsInCurrentRole"], color = 'g')
# Out:
# <AxesSubplot:xlabel='YearsInCurrentRole', ylabel='Density'>

# %%
sn.distplot(new_data["YearsSinceLastPromotion"], color = 'g')
# Out:
# <AxesSubplot:xlabel='YearsSinceLastPromotion', ylabel='Density'>

# %%
sn.distplot(new_data["YearsWithCurrManager"], color = 'g')
# Out:
# <AxesSubplot:xlabel='YearsWithCurrManager', ylabel='Density'>

# %%
new_data.skew()
# Out:
# Age                         0.472280
# Attrition                   1.805983
# DailyRate                  -0.017078
# Department                  0.183919
# DistanceFromHome           -0.031570
# Education                  -0.289024
# EducationField              0.544868
# EnvironmentSatisfaction    -0.325285
# Gender                     -0.417296
# JobInvolvement             -0.501401
# JobLevel                    1.126075
# JobRole                    -0.386843
# JobSatisfaction            -0.345612
# MaritalStatus              -0.160952
# MonthlyIncome               0.318873
# MonthlyRate                 0.030596
# NumCompaniesWorked          0.101288
# OverTime                    0.954751
# PercentSalaryHike           0.496106
# RelationshipSatisfaction   -0.295686
# StockOptionLevel            0.962332
# TotalWorkingYears          -0.728348
# TrainingTimesLastYear       0.577614
# WorkLifeBalance            -0.557100
# YearsAtCompany             -0.379527
# ...

# %% [markdown]
# ### after applying log transformation we can see the skewness get removed/reduced.

# %% [markdown]
# ## Seperating the columns into featuers and target:

# %% [markdown]
# #### x= features, y=Target

# %%
x = new_data.drop(columns = 'Attrition', axis=1)
y = new_data['Attrition']

# %%
#visualization of target variable 
sn.countplot(new_data["Attrition"])
plt.show()

# %%
y.value_counts()
# Out:
# 0    1158
# 1     229
# Name: Attrition, dtype: int64

# %%
#import Libraries
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
x_scaled = ss.fit_transform(x)

# %%
from imblearn.over_sampling import RandomOverSampler  #Random Over Sampler
ROS = RandomOverSampler()
x_res, y_res = ROS.fit_resample(x_scaled, y) # it will resample the data
print(y_res.value_counts()) # after this all classes will be balaned
# Out:
# 1    1158
# 0    1158
# Name: Attrition, dtype: int64

# %%
y_res.value_counts()
# Out:
# 1    1158
# 0    1158
# Name: Attrition, dtype: int64

# %%
#visualization of target variable 
sn.countplot(y_res)
plt.show()

# %% [markdown]
# ## Scalling technique

# %% [markdown]
# variables are scaled now using standard scaler technique.

# %% [markdown]
# ## Variance inflation factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif["vif"] = [variance_inflation_factor(x_res, i) for i in range(x_res.shape[1])]
vif["Features"] = x.columns

#lets check the values
vif
# Out:
#          vif                  Features
# 0   1.921136                       Age
# 1   1.037179                 DailyRate
# 2   2.351432                Department
# 3   1.034336          DistanceFromHome
# 4   1.073114                 Education
# 5   1.053328            EducationField
# 6   1.048320   EnvironmentSatisfaction
# 7   1.037975                    Gender
# 8   1.057945            JobInvolvement
# 9   5.918305                  JobLevel
# 10  2.265439                   JobRole
# 11  1.043878           JobSatisfaction
# 12  2.005585             MaritalStatus
# 13  6.678461             MonthlyIncome
# 14  1.041253               MonthlyRate
# 15  1.469495        NumCompaniesWorked
# 16  1.061548                  OverTime
# 17  1.039670         PercentSalaryHike
# 18  1.046200  RelationshipSatisfaction
# 19  1.925152          StockOptionLevel
# 20  4.549024         TotalWorkingYears
# 21  1.033953     TrainingTimesLastYear
# 22  1.034752           WorkLifeBalance
# ...

# %% [markdown]
# as we see above vif value of all columns is less than 10. so its safe to proceed further.

# %% [markdown]
# ## Finding best random state

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
from sklearn.tree import DecisionTreeClassifier
maxAccu = 0
maxRS = 0
for i in range(1,200):
    x_train, x_test, y_train, y_test = train_test_split(x_res,y_res, test_size=.30, random_state=i)
    mod= DecisionTreeClassifier()
    mod.fit(x_train, y_train)
    pred = mod.predict(x_test)
    acc=accuracy_score(y_test, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Best accuracy is ",maxAccu, "on Random_state ", maxRS)
# Out:
# Best accuracy is  0.9424460431654677 on Random_state  53

# %%
x_train,x_test,y_train,y_test = train_test_split(x_res, y_res, test_size=0.2, random_state = 53)

# %% [markdown]
# ## 1.Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

Log_reg =LogisticRegression()
Log_reg.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
pred_test=Log_reg.predict(x_test)

# %%
print(accuracy_score(y_test,pred_test))
print(confusion_matrix(y_test,pred_test))
print(classification_report(y_test,pred_test))
# Out:
# 0.7844827586206896
# [[183  51]
#  [ 49 181]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.78      0.79       234
#            1       0.78      0.79      0.78       230
#
#     accuracy                           0.78       464
#    macro avg       0.78      0.78      0.78       464
# weighted avg       0.78      0.78      0.78       464

# %%
from sklearn.model_selection import cross_val_score
cv_score= cross_val_score(Log_reg, x_res, y_res, cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.7759011692857676

# %% [markdown]
# ###### The Accuracy score for logistic regression model is : 79.09%
# ###### Cross validation score for logistic regression is : 76.98%

# %% [markdown]
# ## 2.Random forest Classifier

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

parameters ={'criterion':['gini', 'entropy'], 'max_features':["auto","sqrt","log2"]}
Rfr= RandomForestClassifier()
clf =GridSearchCV(Rfr, parameters)
clf.fit(x_train, y_train)

print(clf.best_params_)
# Out:
# {'criterion': 'gini', 'max_features': 'sqrt'}

# %%
Rfr =RandomForestClassifier(criterion = "gini", max_features="sqrt")
Rfr.fit(x_train, y_train)
Rfr.score(x_train, y_train)
pred_decision = Rfr.predict(x_test)

Rfrs = accuracy_score(y_test,pred_decision)
print('accuracy score: ',Rfrs*100)

Rfrscore = cross_val_score(Rfr, x_res, y_res, cv=3)
Rfrc = Rfrscore.mean()
print('Cross Val Score: ',Rfrc*100)
# Out:
# accuracy score:  98.27586206896551
# Cross Val Score:  97.36614853195165

# %% [markdown]
# ###### The Accuracy score for Random Forest Classifier model is : 98.27%
# ###### Cross validation score for Random Forest Classifier is : 97.36%

# %% [markdown]
# ## 3.Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

DT = DecisionTreeClassifier()
DT.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_DT = DT.predict(x_test)
print(accuracy_score(y_test,pred_DT))
# Out:
# 0.9288793103448276

# %%
print(confusion_matrix(y_test,pred_DT))
print(classification_report(y_test,pred_DT))
# Out:
# [[201  33]
#  [  0 230]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.86      0.92       234
#            1       0.87      1.00      0.93       230
#
#     accuracy                           0.93       464
#    macro avg       0.94      0.93      0.93       464
# weighted avg       0.94      0.93      0.93       464

# %%
from sklearn.model_selection import cross_val_score
cv_score= cross_val_score(DT, x_res, y_res, cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.9145118045728756

# %% [markdown]
# ###### The Accuracy score for Decision tree Classifier model is : 92.88%
# ###### Cross validation score for Decision tree Classifier is : 91.45%

# %% [markdown]
# ## 4.Support vector Classifier

# %%
from sklearn.svm import SVC

sv = SVC()
sv.fit(x_train, y_train)
# Out:
# SVC()

# %%
pred_sv = sv.predict(x_test)
print(accuracy_score(y_test,pred_sv))
# Out:
# 0.9051724137931034

# %%
print(confusion_matrix(y_test,pred_sv))
print(classification_report(y_test,pred_sv))
# Out:
# [[204  30]
#  [ 14 216]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.87      0.90       234
#            1       0.88      0.94      0.91       230
#
#     accuracy                           0.91       464
#    macro avg       0.91      0.91      0.91       464
# weighted avg       0.91      0.91      0.91       464

# %%
cv_score= cross_val_score(sv, x_res, y_res, cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.9028487376182319

# %% [markdown]
# ###### The Accuracy score for SVC model is : 90.51%
# ###### Cross validation score for SVC is : 90.28%

# %% [markdown]
# ## Comparison of all model

# %% [markdown]
# #### The difference between Cross validation score  and logistic regression model is: 2.11%
# #### The difference between Cross validation score  and Random Forest Classifier model is: 0.91%
# #### The difference between Cross validation score  and Decision tree Classifier  model is: 1.43%
# #### The difference between Cross validation score  and SVC model is: 0.23%

# %% [markdown]
# ### as shown in above table Logistic degression is having minimum difference, so Decision tree Classifier is best model

# %% [markdown]
# ## Hyper parameter tunning

# %%
# Decision tree Classifier
Parameters = {'max_depth': [2, 3, 5, 10, 20],
              'min_samples_leaf': [1, 10, 20, 50, 100],
              'criterion': ["gini", "entropy"],
              'splitter' : ["best", "random"]
             }

# %%
GCV=GridSearchCV(DecisionTreeClassifier(),Parameters,cv=5)

# %%
GCV.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 5, 10, 20],
#                          'min_samples_leaf': [1, 10, 20, 50, 100],
#                          'splitter': ['best', 'random']})

# %%
GCV.best_params_ # printing the best parameters found by GridSearchCV
# Out:
# {'criterion': 'entropy',
#  'max_depth': 20,
#  'min_samples_leaf': 1,
#  'splitter': 'random'}

# %%
mod = DecisionTreeClassifier( criterion= 'entropy', max_depth= 20, min_samples_leaf= 1, splitter='random')

mod.fit(x_train, y_train)
pred =mod.predict(x_test)
print(accuracy_score(y_test, pred)*100)
# Out:
# 92.88793103448276

# %% [markdown]
# after hyper parameter tunning accuracy score raise to: 92.88%

# %% [markdown]
# ## Boosting of model with adaboost¶

# %%
from sklearn.ensemble import GradientBoostingClassifier
ada = GradientBoostingClassifier()

# %%
ada.fit(x_train, y_train)
y_pred = ada.predict(x_train)

# %%
from sklearn import metrics
print('accuracy square score', metrics.accuracy_score(y_train, y_pred))
# Out:
# accuracy square score 0.9368250539956804

# %% [markdown]
# after boosting of model the model accuracy raise to : 93.68%

# %% [markdown]
# ## ROC AUC curve to choose best model

# %%
# plot ROC/AUC for multiple models

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import plot_roc_curve

# %%
lr = LogisticRegression()
rf = RandomForestClassifier()
dt = DecisionTreeClassifier()
sv = SVC()

# %%
#train all classifiers
lr.fit(x_train, y_train)
rf.fit(x_train, y_train)
dt.fit(x_train, y_train)
sv.fit(x_train, y_train)

print("Now all models are trained")
# Out:
# Now all models are trained

# %%
#All model score captured

lr.score(x_train, y_train)
rf.score(x_train, y_train)
dt.score(x_train, y_train)
sv.score(x_train, y_train)

print("all model test score captured")
# Out:
# all model test score captured

# %% [markdown]
# ## find ROC AUC Score

# %%
#logistic Regression
roc_auc_score(y_test, lr.predict(x_test))
# Out:
# 0.7845039018952064

# %%
# Random Forest Classifier
roc_auc_score(y_test, rf.predict(x_test))
# Out:
# 0.982905982905983

# %%
#Decision Tree Classifier
roc_auc_score(y_test, dt.predict(x_test))
# Out:
# 0.9423076923076923

# %%
#SVC
roc_auc_score(y_test, sv.predict(x_test))
# Out:
# 0.9054626532887402

# %% [markdown]
# ## Ploting AUC ROC curve

# %%
disp = plot_roc_curve(dt, x_test, y_test)

plot_roc_curve(lr, x_test, y_test, ax=disp.ax_)

plot_roc_curve(rf, x_test, y_test, ax=disp.ax_)

plot_roc_curve(dt, x_test, y_test, ax=disp.ax_)

plot_roc_curve(sv, x_test, y_test, ax=disp.ax_)

plt.legend(prop = {'size':11}, loc='lower right')

plt.show()

# %% [markdown]
# ## Saving the model

# %%
import joblib
joblib.dump(mod,"HRanalytics.pkl")
# Out:
# ['HRanalytics.pkl']

# %% [markdown]
# ## Loding model

# %%
model = joblib.load("HRanalytics.pkl")

# %%
prediction = model.predict(x_test)

# %%
prediction=pd.DataFrame(prediction)
#converted into data frame

# %%
prediction.to_csv('HRanalyticsResults.csv', index = False)
#prediction saving

# %% [markdown]
# model saved
